# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import string
from sklearn.model_selection import train_test_split
from keras import regularizers


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Embedding
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Embedding
from tensorflow.keras.layers import SpatialDropout1D, Conv1D, Bidirectional, LSTM, Dense, Input, Dropout, GlobalMaxPooling1D
from keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv(r'/content/gdrive/MyDrive/ArSAS..txt',delimiter='\t')
data
# Out:
#                 #Tweet_ID                                         Tweet_text  \
# 0      929241870508724224  المباراة القـادمة #غانا x #مصر الجولة الأخيرة ...
# 1      928942264583376897  هل هذه هي سياسة خارجيه لدوله تحترم نفسها والآخ...
# 2      928615163250520065  وزير خارجية فرنسا عن منتدى شباب العالم: شعرت ب...
# 3      931614713368186880  ومع السيسي و بشار و ايران و بن زايد و والا خلي...
# 4      929755693011427331  أهداف مباراة غانا 0 مصر 1 تصفيات كأس العالم 20...
# ...                   ...                                                ...
# 19892  929109605267000960  ملخص مباراة نيجيريا vs الجزائر تصفيات كأس 🏆 ال...
# 19893  930131859039837952  ايطاليا في السان سيرو لعبت 42 مباراة 🇮🇹 31 فوز...
# 19894  928739551136361984  المُلحق المؤهل لكأس العالم 🇪🇺أوروبا🇪🇺 مباراة ا...
# 19895  929254320754823168  رسائل وتوصيات منتدى شباب العالم .. د. عبدالله ...
# 19896  931274896897904640  لماذا الحكومات لم تحاسبهم؟ ربما تحريضهم للشباب...
#
#                Topic Sentiment_label  Sentiment_label_confidence  \
# 0              Event        Positive                        0.38
# 1             Entity        Negative                        1.00
# 2              Event        Positive                        0.69
# 3              Event        Negative                        1.00
# 4              Event         Neutral                        1.00
# ...              ...             ...                         ...
# 19892          Event         Neutral                        1.00
# 19893          Event        Positive                        0.69
# 19894          Event         Neutral                        1.00
# 19895          Event         Neutral                        1.00
# 19896  Long_Standing        Negative                        1.00
#
#       Speech_act_label  Speech_act_label_confidence
# 0            Assertion                         0.62
# 1           Expression                         0.68
# 2            Assertion                         1.00
# 3           Expression                         1.00
# 4            Assertion                         1.00
# ...                ...                          ...
# 19892        Assertion                         1.00
# 19893       Expression                         0.69
# 19894        Assertion                         1.00
# 19895        Assertion                         1.00
# 19896       Expression                         1.00
#
# [19897 rows x 7 columns]

# %%
print("On a  {} doublons dans Data.".format(data.duplicated().sum()))

data.drop_duplicates(inplace = True)

print("On a  {} doublons dans Data.".format(data.duplicated().sum()))
# Out:
# On a  26 doublons dans Data.
# On a  0 doublons dans Data.

# %%
def preprocessing(x):
    x = re.sub('@[^\s]+', ' ', x)
    x = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',x)

    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030""]+", flags=re.UNICODE)
    emoji_pattern.sub(r'', x)

    ar_punctuations = '''`÷×؛<>_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ#'''
    en_punctuations = string.punctuation
    punctuations = ar_punctuations + en_punctuations
    x = x.translate(str.maketrans('', '', punctuations))

    arabic_diacritics = re.compile(""" ّ    | # Tashdid
                             َ    | # Fatha
                             ً    | # Tanwin Fath
                             ُ    | # Damma
                             ٌ    | # Tanwin Damm
                             ِ    | # Kasra
                             ٍ    | # Tanwin Kasr
                             ْ    | # Sukun
                             ـ     # Tatwil/Kashida
                         """, re.VERBOSE)
    x = re.sub(arabic_diacritics, '', str(x)) 

#     x = re.sub("[إأآا]", "ا", x)
#     x = re.sub("ى", "ي", x)
#     x = re.sub("ة", "ه", x)
#     x = re.sub("گ", "ك", x)
#     x = re.sub(r'(.)\1+', r'\1', x)

    return x

# %%
data["Clean_tweets"] = data.Tweet_text.apply(lambda x: preprocessing(str(x)))

# %%
data["Topics"] = data['Topic'].astype("category").cat.codes

# %%
data["Topics"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 19892    1
# 19893    1
# 19894    1
# 19895    1
# 19896    2
# Name: Topics, Length: 19871, dtype: int8

# %%
K = data["Topics"].max() + 1
K
# Out:
# 3

# %%
X = data.Clean_tweets
y = data.Topics

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size = 0.20, 
                                                    random_state = 42)

"""**printing the number of the train set and the test set**"""

print('Train set', X_train.shape)
print('Test set', X_test.shape)
# Out:
# Train set (15896,)
# Test set (3975,)

# %%
MAX_VOCAB_SIZE=250000
tokenizer=Tokenizer(num_words=MAX_VOCAB_SIZE,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(X_train)

# %%
word_index = tokenizer.word_index
vocab_size = len(tokenizer.word_index) + 1

# %%
MAX_SEQUENCE_LENGTH = 3456
# 
X_train = pad_sequences(tokenizer.texts_to_sequences(X_train),
                         maxlen = MAX_SEQUENCE_LENGTH)
X_test = pad_sequences(tokenizer.texts_to_sequences(X_test),
                        maxlen = MAX_SEQUENCE_LENGTH)
#

# %%
import gensim
from gensim.models import KeyedVectors
import itertools
from numpy import loadtxt
from keras.models import load_model

# %%
#target_word_vec = gensim.models.KeyedVectors.load_word2vec_format("/content/gdrive/MyDrive/cbow_100.bin", binary = True,unicode_errors='ignore')

target_word_vec = KeyedVectors.load_word2vec_format("/content/gdrive/MyDrive/cc.ar.300.vec", binary = False)

# %%
embedding_matrix = np.zeros((vocab_size, 300))
# 
for word, i in word_index.items():
     if word in target_word_vec :
         embedding_vector = target_word_vec[word]
         if embedding_vector is not None:
             embedding_matrix[i] = embedding_vector

embedding_matrix.shape[0] == vocab_size
# Out:
# True

# %%
model = Sequential()
embedding_layer = Embedding(vocab_size, 
                            300, 
                            weights = [embedding_matrix], 
                            input_length = MAX_SEQUENCE_LENGTH, 
                            trainable=False)
model.add(embedding_layer)
model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
model.add(Bidirectional(LSTM(64, dropout=0.2, return_sequences=True)))
model.add(GlobalMaxPooling1D())
model.add(Dropout(0.2))
model.add(Dense(K, activation='sigmoid'))

# %%
model.compile(optimizer = Adam(learning_rate=0.001), 
             loss=SparseCategoricalCrossentropy(),
              metrics = ['accuracy'])

# %%
r = model.fit(
  X_train,
  y_train,
  batch_size = 64,
  epochs=20,
  validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# 249/249 [==============================] - 81s 258ms/step - loss: 0.4376 - accuracy: 0.8164 - val_loss: 0.2261 - val_accuracy: 0.9125
# Epoch 2/20
# 249/249 [==============================] - 59s 238ms/step - loss: 0.1982 - accuracy: 0.9266 - val_loss: 0.2031 - val_accuracy: 0.9228
# Epoch 3/20
# 249/249 [==============================] - 64s 256ms/step - loss: 0.1723 - accuracy: 0.9368 - val_loss: 0.1746 - val_accuracy: 0.9316
# Epoch 4/20
# 249/249 [==============================] - 59s 238ms/step - loss: 0.1498 - accuracy: 0.9452 - val_loss: 0.1662 - val_accuracy: 0.9364
# Epoch 5/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.1286 - accuracy: 0.9536 - val_loss: 0.1629 - val_accuracy: 0.9394
# Epoch 6/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.1195 - accuracy: 0.9594 - val_loss: 0.1715 - val_accuracy: 0.9341
# Epoch 7/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.1039 - accuracy: 0.9624 - val_loss: 0.1564 - val_accuracy: 0.9406
# Epoch 8/20
# 249/249 [==============================] - 60s 239ms/step - loss: 0.0896 - accuracy: 0.9683 - val_loss: 0.1636 - val_accuracy: 0.9406
# Epoch 9/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.0777 - accuracy: 0.9729 - val_loss: 0.1658 - val_accuracy: 0.9411
# Epoch 10/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.0719 - accuracy: 0.9755 - val_loss: 0.1770 - val_accuracy: 0.9394
# Epoch 11/20
# 249/249 [==============================] - 64s 258ms/step - loss: 0.0702 - accuracy: 0.9767 - val_loss: 0.1810 - val_accuracy: 0.9416
# Epoch 12/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.0585 - accuracy: 0.9810 - val_loss: 0.1749 - val_accuracy: 0.9452
# Epoch 13/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.0529 - accuracy: 0.9829 - val_loss: 0.1882 - val_accuracy: 0.9414
# Epoch 14/20
# 249/249 [==============================] - 60s 239ms/step - loss: 0.0470 - accuracy: 0.9837 - val_loss: 0.2119 - val_accuracy: 0.9411
# Epoch 15/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.0434 - accuracy: 0.9859 - val_loss: 0.1816 - val_accuracy: 0.9442
# Epoch 16/20
# 249/249 [==============================] - 60s 239ms/step - loss: 0.0357 - accuracy: 0.9875 - val_loss: 0.1903 - val_accuracy: 0.9462
# Epoch 17/20
# 249/249 [==============================] - 64s 256ms/step - loss: 0.0372 - accuracy: 0.9867 - val_loss: 0.2252 - val_accuracy: 0.9419
# Epoch 18/20
# 249/249 [==============================] - 60s 239ms/step - loss: 0.0340 - accuracy: 0.9874 - val_loss: 0.2171 - val_accuracy: 0.9396
# Epoch 19/20
# 249/249 [==============================] - 59s 238ms/step - loss: 0.0329 - accuracy: 0.9883 - val_loss: 0.1873 - val_accuracy: 0.9469
# Epoch 20/20
# 249/249 [==============================] - 64s 257ms/step - loss: 0.0303 - accuracy: 0.9898 - val_loss: 0.2048 - val_accuracy: 0.9467
